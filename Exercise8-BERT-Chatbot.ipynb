# %%
# !pip install transformers
from transformers import pipeline

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

# %%
def get_text(url,result):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'  # Update User-Agent if needed
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Check for HTTP errors

        soup = BeautifulSoup(response.content, "html.parser")

        result = soup.get_text(strip=True)
        print (result)

        lines = (line.strip() for line in all_text.splitlines())
        lines = list(line for line in lines if line)

        print("All Text (Cleaned):\n")
        for line in lines:
            print(line)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {url} - {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
#url = "https://docs.google.com/document/d/1xcfco6WCiCsW9BVF5llJ-4BnPzzclhTFniLVCtz1FpI/edit?tab=t.0"  # Or any other URL
url = "https://fremontunified.org/american/about/office/ahs-administration/"
#url = "https://fremontunified.org/american/students-community/departments-programs/academics/ap-testing-spring-2025/"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'  # Update User-Agent if needed
    }

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Extract all text
text = soup.get_text()

# Print or save the text
print(text)
# Out:
#
#
# Attention Required! | Cloudflare
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please enable cookies.
#
#
# Sorry, you have been blocked
# You are unable to access fremontunified.org
#
#
#
#
#
#
#
#
#
#
#
# Why have I been blocked?
# This website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.
#
#
# What can I do to resolve this?
# You can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.
#
#
#
#
#
# Cloudflare Ray ID: 93b60bae8f22ffee
# •
#
#         Your IP:
#         Click to reveal
# 34.90.166.63
# •
#
# Performance & security by Cloudflare

# %%
url = "https://fremontunified.org/american"  # Or any other URL
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'  # Update User-Agent if needed
    }

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Extract all text
text = soup.get_text()

# Print or save the text
print(text)
# Out:
# Home - American
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# American
#
#
#
#
#
#
#
#
# High School
#
#
#
#
#
#
#
#
#
#
#
#
#  Site Menu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About
#
#
#
#
#
#
#
#
#
#
#
#
# Welcome to AHSStaff DirectoryOffice & PrincipalsPolicies & Handbook
#
#
#
#
#
#
#
#
# Students & Community
#
#
#
#
#
#
#
#
#
#
#
#
# Student SupportDepartments & ProgramsActivities & AthleticsCommunity Connections
#
#
#
#
#
#
#
#
# Schedule & News
#
#
#
#
#
#
#
#
#
#
#
#
# Bell ScheduleCalendarNews & UpdatesEvents & Tickets
#
#
#
#
#
#
#
#
# Resources
#
#
#
#
#
#
#
#
#
#
#
#
# School SafetyChild Nutrition & MenusReports & PlansConcerns & Complaints
#
#
#
#
#
#
#
#
#
#
#
#
# Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
# Enroll
#
#
#
#
#
#
#
#
#
# ...

# %%
question_answerer = pipeline("question-answering", model="deepset/roberta-base-squad2")
result= question_answerer("Who is the assistant principal of american high?", text)
#result = question_answerer({
#      "question": "Who is the principal of american high?",
#      "context": text
#})

print(result)
# Out:
# Device set to use cpu
# {'score': 0.7710465788841248, 'start': 5517, 'end': 5529, 'answer': 'Zahra Pelayo'}
