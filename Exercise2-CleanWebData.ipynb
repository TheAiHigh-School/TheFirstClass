# %%
import requests
from bs4 import BeautifulSoup

#url = "https://www.nvidia.com"
url = "https://www.apple.com"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Extract all text
all_text = soup.get_text(strip=True)

# Print or save the text
print("All Text:\n", all_text)

words = re.findall(r'\b\w+\b', all_text.lower())
word_count = len(words)
print("\nWord Count:", word_count)

sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|!)\s', all_text)
apple_sentences = [sentence.strip() for sentence in sentences if "apple" in sentence.lower()]

print("\nSentences with 'apple':")
if apple_sentences:
    for sentence in apple_sentences:
      print(sentence)
else:
      print("No sentences containing 'apple' found.")


# Optionally, save to a file
#with open('apple_text.txt', 'w', encoding='utf-8') as f:
#    f.write(text)
# Out:
# All Text:
# ...
